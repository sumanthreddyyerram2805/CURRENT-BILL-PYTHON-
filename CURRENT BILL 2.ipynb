# %% [markdown]
# # CURRENT BILL

# %%
name=input("Enter name")
units=int(input("Enter units"))
if units<=100:
    amount=units*2
    print("The Total amount",amount)
elif units<=200:
     amount=100*2+(units-100)*3
elif units<=300:
     amount=100*2+100*3+(units-200)*4
elif units<=500:
     amount=100*2+100*3+100*4+(units-300)*5
elif units>500:
     amount=100*2+100*3+100*4+200*5+(units-500)*6
     surcharge=amount*0.10
     amount=amount+surcharge
     print("Final Amount is",amount)
print('Final Amount is',amount)
